# %%
import os
import time
import subprocess
import json

# %%
import wolframalpha
import requests
import webbrowser
import wikipedia
import datetime

# %%
import speech_recognition as sr
import pyttsx3

# %%
print("LOADING YOUR A.I PERSONAL ASSISTANT JARVIS")
# Out:
# LOADING YOUR A.I PERSONAL ASSISTANT JARVIS

# %%
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty("voice",'voices[0].id')

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def wishMe():
    hour = datetime.datetime.now().hour
    if hour >= 0 and hour < 12:
        speak("Hello, Good Morning Ms. Sampati")
        print("Hello, Good Morning Ms. Sampati")
    elif hour >=12 and hour <=18:
        speak("Hello, Good Evening Ms. Sampati")
        print("Hello, Good Evening Ms. Sampati")
    else:
        speak("Time to sleep Ms. Sampati")
        print("Time to sleep Ms. Sampati")

# %%
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("I am listening...")
        try:
            audio = r.listen(source, timeout=5, phrase_time_limit=7)
            statement = r.recognize_google(audio, language='en-in')
            print(f"You said: {statement}")
            return statement
        except sr.WaitTimeoutError:
            print("Listening timed out while waiting for phrase to start.")
            return ""
        except sr.UnknownValueError:
            print("Sorry, I did not understand that.")
            return ""
        except sr.RequestError:
            print("Could not request results from the speech recognition service.")
            return ""
        return statement

# %%
speak("LOADING YOUR A.I PERSONAL ASSISTANT JARVIS")
wishMe()
# Out:
# Hello, Good Evening Ms. Sampati

# %%
if __name__=='__main__':
    while True:
        speak("How can I help you?")
        statement = takeCommand().lower()
        if statement == 0:
            continue
        if "Good bye" in statement or "Ok bye" in statement or "stop" in statement:
            speak("Your personal AI assistant JARVIS is shutting down, Goodbye")
            print("Your personal AI assistant JARVIS is shutting down, Goodbye")
            break
            
        if 'wikipedia' in statement:
            speak("Searching Wikipedia....")
            statement = statement.replace("wikipedia"," ")
            results =  wikipedia.summary(statement, sentence=3)
            speak("According to wikipedia...")
            print(results)
            speak(results)
            
        elif "open youtube" in statement:
            webbrowser.open_new_tab("https://www.youtube.com")
            speak("Youtube is open for you")
            time.sleep(5)
            
        elif "open google" in statement:
            webbrowser.open_new_tab("https://www.google.com")
            speak("Google search is open for you")
            time.sleep(5)
            
        elif "open gmail" in statement:
            webbrowser.open_new_tab("https://www.gmail.com")
            speak("Gmail is open for you")
            time.sleep(5)
            
            
        elif "weather" in statement:
            api_key="8ef61edcf1c576d65d836254e11ea420"
            base_url="https://api.openweathermap.org/data/2.5/weather?"
            speak("What is the city name?")
            city_name = takeCommand()
            complete_url= base_url+"appid ="+api_key+"&q="+city_name
            response =  requests.get(complete_url)
            x = response.json()
            if x["cod"]!= "404":
                y=x["main"]
                current_temperature = y["temp"]
                current_humidity=  y["humidity"]
                z=x["weather"]
                weather_description= z[0]["description"]
                speak("The temperature in Kelvin units is" +str(current_temperature)+"\n humidity in percentage is"+str(current_humidity)+"\n weather description"+str(weather_description))
                print("The temperature in Kelvin units is" +str(current_temperature)+"\n humidity in percentage is"+str(current_humidity)+"\n weather description"+str(weather_description)) 
            else:
                speak("City not found")
                print("City not found")
                
        elif "time" in statement:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"The time is {strTime}")
            
        elif "who are you" in statement or "what can you do" in statement:
            speak("I'm your personal AI assistant JARVIS and can do some programmed tasks")
    
        elif "who made you" in statement or "who created you" in statement:
            speak("I was built by Sampati")
            
        elif "open stack overflow" in statement:
            webbrowser.open_new_tab("https://www.stackoverflow.com/login")
            time.sleep(5)
            
        elif "news" in statement:
            webbrowser.open_new_tab("https://timeofindia.indiatimes.com/home/headlines")
            speak("heere are some headlines for you from times of India -  happy reading")
            times.sleep(7)
            
        elif "search" in statement:
            statement =  statement.replace("search"," ")
            webbrowser.open_new_tab("statement")
            time.sleep(5)
            
        elif "ask" in statement:
            speak("I can answer to computational and geogrphical questions too just try me")
            question = takeCommand()
            app_id = "R2K75H-7ELALHR35X"
            client = wolframalpha.Client('R2K75H-7ELALHR35X')
            res = client.query(question)
            answer = next(res.results).text
            speak(answer)
            print(answer)
            
        elif "log off" in statement or "sign out" in statement or "shut down" in statement:
            speak("ok, your PC will shut down in 10 seconds -  make sure you have saved and exit from all application")
            subprocess.call(['shutdown',"/1"])
        
time.sleep(3)
# Out:
# I am listening...
# You said: ask
# I am listening...
# Sorry, I did not understand that.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#      83 app_id = "R2K75H-7ELALHR35X"
#      84 client = wolframalpha.Client('R2K75H-7ELALHR35X')
# ---> 85 res = client.query(question)
#      86 answer = next(res.results).text
#      87 speak(answer)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\wolframalpha\__init__.py:119, in Client.query(self, input, params, **kwargs)
#      97 def query(self, input, params=(), **kwargs):
#      98     """
#      99     Query Wolfram|Alpha using the v2.0 API
#     100
#    (...)
#     117     https://products.wolframalpha.com/api/documentation.html#6
#     118     """
# --> 119     return asyncio.run(self.aquery(input, params, **kwargs))
#
# File ~\anaconda3\lib\asyncio\runners.py:33, in run(main, debug)
# ...
